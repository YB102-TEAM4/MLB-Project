# %%
#首先Name要排序
#要注意的地方有四個 range, year, fileName, page_limit
import string
import time
import requests
from bs4 import BeautifulSoup
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.93 Safari/537.36'
}
url='http://www.baseballprospectus.com/sortable/index.php'      
for year in range(1871,2015): #2015沒算到**************
    payload={
            'mystatslist':'TEAM,LG,YEAR,G,PA,AB,R,H,HR,TB,BB,IBB,SO,BBR,SOR,HBP,SF,SH,RBI,SB,CS,SB_PERCENT,AVG,OBP,SLG,OPS,ISO,BPF,EQA,VORP',
            'category':'team_batting',
            'tablename':'dyna_team_batting',
            'stage':'data',
            'year':'%d'%(year),#*********************
            'mystatslist':'TEAM,LG,YEAR,G,PA,AB,R,H,HR,TB,BB,IBB,SO,BBR,SOR,HBP,SF,SH,RBI,SB,CS,SB_PERCENT,AVG,OBP,SLG,OPS,ISO,BPF,EQA,VORP',
            'category':'team_batting',
            'tablename':'dyna_team_batting',
            'stage':'data',
            'group_TEAM':'*',
            'group_LVL':'MLB',
            'group_LG':'*',
            'minimum':'0',
            'sort1column':'TEAM',
            'sort1order':'ASC',
            'page_limit':'All',#*********************
            'viewdata':'View Data',
        }
    res=requests.post(url,data=payload,headers=headers)
    soup=BeautifulSoup(res.text.encode('utf-8'))    
    trList=soup.select('#TTdata tr')
    fileName= str(year)+'_TeamBattingStandard.csv'#*********************
    fid=open('Baseball\\'+fileName,'w')    
    for tr in trList:
        for td in tr.select('td'):
            fid.write(td.text.encode('utf-8')+',')
        fid.write('\n')
    fid.close()
    fod=open('Baseball\\'+fileName,'r')
    print 'year'+str(year)
    print fod.readlines()[1]
    fod.close()
    time.sleep(2)
# Out:
# year1871
# 1.,BS1,NA,1871,31,1,432,1,372,401,426,3,579,60,0,19,0.042,0.013,0,0,0,267,73,16,82.0%,.310,.000,.422,.000,.112,,.000,0.0,
#
# year1872
# 1.,BL1,NA,1872,58,2,600,2,571,617,753,14,963,29,0,28,0.011,0.011,0,0,0,379,53,18,74.7%,.293,.000,.375,.000,.082,,.000,0.0,
#
# year1873
# 1.,BL1,NA,1873,57,2,603,2,560,644,810,9,1026,43,0,30,0.017,0.012,0,0,0,427,28,13,68.3%,.316,.000,.401,.000,.084,,.000,0.0,
#
# year1874
# 1.,BL1,NA,1874,47,1,798,1,776,227,435,1,497,22,0,37,0.012,0.021,0,0,0,141,12,5,70.6%,.245,.000,.280,.000,.035,,.000,0.0,
#
# year1875
# 1.,BR2,NA,1875,44,1,562,1,554,130,302,2,353,8,0,36,0.005,0.023,0,0,0,86,1,5,16.7%,.194,.000,.227,.000,.033,,.000,0.0,
#
# year1876
# 1.,BSN,NL,1876,70,2,780,2,722,471,723,9,894,58,0,98,0.021,0.035,0,0,0,281,0,0,0.0%,.266,.000,.328,.000,.063,,.000,0.0,
#
# year1877
# 1.,BSN,NL,1877,61,2,433,2,368,419,700,4,877,65,0,121,0.027,0.050,0,0,0,291,0,0,0.0%,.296,.000,.370,.000,.075,,.000,0.0,
#
# year1878
# ...
