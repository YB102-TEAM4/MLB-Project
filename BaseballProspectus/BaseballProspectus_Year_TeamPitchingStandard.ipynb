# %%
#首先Name要排序
#要注意的地方有四個 folder, range, year, page_limit
import string, time, requests, os
from bs4 import BeautifulSoup
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.93 Safari/537.36'
}
url='http://www.baseballprospectus.com/sortable/index.php'

folder='TeamPitchingStandard'#資料夾名稱*********************
path='Baseball\\'+folder #路徑名稱
if os.path.exists(path):
    print 'folder exists'
else:    
    os.mkdir(path)
    print 'folder not exists'  
    
for year in range(1871,2015): #2015沒算到**************
    payload={
            'mystatslist':'YEAR,TEAM,LG,LVL,IP,W,L,SV,BS,HD,G,GS,PA,AB,H,B1,B2,HR,TB,R,ER,BB,UBB,SO,BBR,UBBR,SOR,HBP,SF,SH,ERA,FAIR_RA,VORP',
            'category':'team_pitching',
            'tablename':'dyna_team_pitching',
            'stage':'data',
            'year':'%d'%(year),
            'mystatslist':'YEAR,TEAM,LG,LVL,IP,W,L,SV,BS,HD,G,GS,PA,AB,H,B1,B2,HR,TB,R,ER,BB,UBB,SO,BBR,UBBR,SOR,HBP,SF,SH,ERA,FAIR_RA,VORP',
            'category':'team_pitching',
            'tablename':'dyna_team_pitching',
            'stage':'data',
            'group_LG':'*',
            'group_LVL':'MLB',
            'minimum':'0',
            'sort1column':'TEAM',
            'sort1order':'ASC',
            'page_limit':'All',
            'viewdata':'View Data',
        }
    res=requests.post(url,data=payload,headers=headers)
    soup=BeautifulSoup(res.text.encode('utf-8'))    
    trList=soup.select('#TTdata tr')
    fileName= str(year)+'_'+folder+'.csv'
    fid=open(path+'\\'+fileName,'w')    
    for tr in trList:
        for td in tr.select('td'):
            fid.write(td.text.encode('utf-8')+',')
        fid.write('\n')
    fid.close()
    fod=open(path+'\\'+fileName,'r')
    print 'year'+str(year)
    print fod.readlines()[1]
    fod.close()
    time.sleep(2)
# Out:
# folder not exists
# year1871
# 1.,1871,BS1,NA,MLB,276.0,20,10,3,,,40,31,1,384,0,367,0,0,2,,303,109,42,42,23,0.000,0.000,0.000,0,0,0,3.55,0.00,0.0,
#
# year1872
# 1.,1872,BL1,NA,MLB,516.0,35,19,1,,,68,58,2,404,0,573,0,0,3,,434,166,63,63,77,0.000,0.000,0.000,0,0,0,2.90,0.00,0.0,
#
# year1873
# 1.,1873,BL1,NA,MLB,508.7,34,22,0,,,59,57,2,426,0,680,0,0,4,,451,174,43,43,37,0.000,0.000,0.000,0,0,0,3.08,0.00,0.0,
#
# year1874
# 1.,1874,BL1,NA,MLB,420.0,9,38,0,,,53,47,2,136,0,640,0,0,3,,505,146,39,39,20,0.000,0.000,0.000,0,0,0,3.13,0.00,0.0,
#
# year1875
# 1.,1875,BR2,NA,MLB,396.0,2,42,0,,,58,44,1,894,0,535,0,0,6,,438,139,17,17,16,0.000,0.000,0.000,0,0,0,3.16,0.00,0.0,
#
# year1876
# 1.,1876,BSN,NL,MLB,632.0,39,31,7,,,91,70,2,834,0,732,0,0,7,,450,176,104,104,77,0.000,0.000,0.000,0,0,0,2.51,0.00,0.0,
#
# year1877
# 1.,1877,BSN,NL,MLB,548.0,42,18,0,,,61,61,2,278,0,557,0,0,5,,263,131,38,38,177,0.000,0.000,0.000,0,0,0,2.15,0.00,0.0,
#
# year1878
# ...
