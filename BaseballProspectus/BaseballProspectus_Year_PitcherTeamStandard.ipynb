# %%
#首先Name要排序
#要注意的地方有四個 folder, range, year, page_limit
import string, time, requests, os
from bs4 import BeautifulSoup
headers={
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.93 Safari/537.36'
}
url='http://www.baseballprospectus.com/sortable/index.php'

folder='PitcherTeamStandard'#資料夾名稱*********************

path='Baseball\\'+folder #路徑名稱
if os.path.exists(path):
    print 'folder exists'
else:    
    os.mkdir(path)
    print 'folder not exists'  
    
for year in range(1871,2015): #2015沒算到**************
    payload={            
            'mystatslist':'LVL,NAME,YEAR,AGE,G,GS,PITCHES,IP,FAIR_IP,IP_START,IP_RELIEF,W,L,SV,BS,PA,AB,R,ER,H,B1,B2,B3,HR,TB,BB,UBB,IBB,SO,HBP,SF,SH,ERA,FAIR_RA,PPF,VORP,FIP,PVORP,PWARP',
            'category':'pitcher_season',
            'tablename':'dyna_pitcher_season',
            'stage':'data',
            'year':'%d'%(year),#*********************
            'mystatslist':'LVL,NAME,YEAR,AGE,G,GS,PITCHES,IP,FAIR_IP,IP_START,IP_RELIEF,W,L,SV,BS,PA,AB,R,ER,H,B1,B2,B3,HR,TB,BB,UBB,IBB,SO,HBP,SF,SH,ERA,FAIR_RA,PPF,VORP,FIP,PVORP,PWARP',
            'category':'pitcher_season',
            'tablename':'dyna_pitcher_season',
            'stage':'data',
            'group_LVL':'MLB',
            'minimum':'0',
            'sort1column':'NAME',
            'sort1order':'ASC',
            'page_limit':'All',#*********************
            'glossary_terms':'*',
            'tt_team':'*',
            'show_ttroster':'1',
            'show_ttwatched':'1',
            'viewdata':'View Data',
        }
    res=requests.post(url,data=payload,headers=headers)
    soup=BeautifulSoup(res.text.encode('utf-8'))
    trList=soup.select('#TTdata tr')
    fileName= str(year)+'_'+folder+'.csv'
    fid=open(path+'\\'+fileName,'w')
    for tr in trList:
        for td in tr.select('td'):
            fid.write(td.text.encode('utf-8')+',')
        fid.write('\n')
    fid.close()
    fod=open(path+'\\'+fileName,'r')
    print 'year'+str(year)
    print fod.readlines()[1]
    fod.close()
    time.sleep(2)
# Out:
# folder not exists
# year1871
# 1.,MLB,Al Pratt,1871,23,28,28,,224.7,,0.0,0.0,10,17,0,,1,117,0,288,94,296,0,0,0,9,,47,47,0,34,0,0,0,3.77,0.00,,0.0,4.43,0.0,0.00,
#
# year1872
# 1.,MLB, O'rourke,1872,0,1,1,,9.0,,0.0,0.0,0,1,0,,51,0,15,8,16,0,0,0,0,,2,2,0,0,0,0,0,8.00,0.00,,0.0,4.10,0.0,0.00,
#
# year1873
# 1.,MLB,Al Spalding,1873,22,60,54,,496.7,,0.0,0.0,41,14,3,,2,297,0,413,165,643,0,0,0,5,,36,36,0,50,0,0,0,2.99,0.00,,0.0,3.25,0.0,0.00,
#
# year1874
# 1.,MLB,Al Spalding,1874,23,71,69,,617.3,,0.0,0.0,52,16,0,,2,784,0,402,132,755,0,0,0,1,,19,19,0,31,0,0,0,1.92,0.00,,0.0,2.08,0.0,0.00,
#
# year1875
# 1.,MLB,Al Spalding,1875,24,72,62,,570.7,,0.0,0.0,54,5,9,,2,354,0,241,101,573,0,0,0,1,,18,18,0,75,0,0,0,1.59,0.00,,0.0,2.09,0.0,0.00,
#
# year1876
# 1.,MLB,Al Spalding,1876,25,61,60,,528.7,,0.0,0.0,47,12,0,,2,219,0,226,103,542,0,0,0,6,,26,26,0,39,0,0,0,1.75,0.00,,0.0,2.38,0.0,0.00,
#
# year1877
# ...
